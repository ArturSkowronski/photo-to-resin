# %% [markdown]
# # photo-to-resin — panel sterowania
#
# Zamień zdjęcie w litofan STL bez pisania kodu:
#
# 1. Uruchom komórkę poniżej (`Shift+Enter`).
# 2. Wgraj zdjęcie przyciskiem **Zdjęcie** (bez wgrania panel pokazuje przykładowy pejzaż).
# 3. Kręć suwakami — podgląd podświetlenia odświeża się na żywo.
# 4. Kliknij **Generuj STL**. Plik ląduje obok notebooka, gotowy do slicera.
#
# Wskazówki do druku na żywicy: grubość 0.6–2.8 mm sprawdza się na mlecznych i szarych żywicach; rozdzielczość 4 px/mm to dobry kompromis między detalem a rozmiarem pliku.

# %%
from photo_to_resin.notebook import launch

panel = launch()

# %% [markdown]
# ## To samo z kodu
#
# Jeśli wolisz API zamiast suwaków — cały potok to trzy linijki:

# %%
from photo_to_resin import LithophaneParams, photo_to_stl
from photo_to_resin.sample import make_sample_photo

params = LithophaneParams(width_mm=80, min_thickness_mm=0.6, max_thickness_mm=2.8)
photo_to_stl(make_sample_photo(), "przyklad.stl", params)
